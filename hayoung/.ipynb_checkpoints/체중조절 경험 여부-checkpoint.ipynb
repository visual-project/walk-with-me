# %%
import pandas as pd
import numpy as np

data_raw = pd.read_csv('../raw/지역사회건강조사 1차 전처리_2019.csv')

# %%
data_raw
# Out:
#        Unnamed: 0  만나이  성별  주관적 건강수준  격렬한 신체활동 일수  격렬한 신체활동 시간(시)  \
# 0               0   61   2         4            1               5
# 1               1   66   1         3            1               5
# 2               2   89   2         5            0              88
# 3               3   27   1         4            1               0
# 4               4   42   2         3            2               0
# ...           ...  ...  ..       ...          ...             ...
# 22925       22925   62   2         3            0              88
# 22926       22926   65   1         4            7               2
# 22927       22927   24   1         2            0              88
# 22928       22928   56   2         3            0              88
# 22929       22929   66   2         1            0              88
#
#        격렬한 신체활동 시간(분)  중등도 신체활동 일수  중등도 신체활동 시간(시)  중등도 신체활동 시간(분)  걷기 실천 일수  \
# 0                   0            3               1               0         7
# 1                   0            0              88              88         7
# 2                  88            0              88              88         0
# 3                  10            1               0              10         7
# 4                  30            2               0              10         5
# ...               ...          ...             ...             ...       ...
# 22925              88            7               1               0         5
# 22926               0            7               2               0         0
# 22927              88            0              88              88         7
# 22928              88            0              88              88         3
# 22929              88            7               1               0         7
#
#        걷기 실천 시간(시)  걷기 실천 시간(분)  체중조절 경험 여부  주관적 스트레스 수준  우울감 경험 여부  행복감 지수  \
# 0                1            0           1            3          2       5
# 1                1            0           4            2          2       8
# 2               88           88           4            1          2      77
# 3                0           30           3            2          2       8
# 4                0           20           1            3          2       6
# ...            ...          ...         ...          ...        ...     ...
# 22925            0           20           1            2          2       4
# 22926           88           88           2            2          2      10
# 22927            0           20           1            4          2       7
# 22928            2            0           1            4          2       7
# 22929            1            0           2            4          2      10
#
#        사회환경_동네 자연환경  사회환경_동네 생활환경  자치구
# 0                 2             1  마포구
# 1                 2             1  마포구
# 2                 9             9  마포구
# 3                 1             1  마포구
# 4                 2             2  마포구
# ...             ...           ...  ...
# 22925             9             1  금천구
# 22926             2             2  금천구
# 22927             2             1  금천구
# 22928             1             1  금천구
# 22929             1             1  금천구
#
# [22930 rows x 20 columns]

# %%
data_pbhlth_code = pd.read_excel('../raw/지역사회건강조사 1차 전처리.csv',header=3)
data_pbhlth_code = data_pbhlth_code[data_pbhlth_code['시도코드'] == 11][['보건소코드','보건소명']]

data_pbhlth_code["보건소명"] = data_pbhlth_code["보건소명"].str.replace('보건소', '', regex=True)
data_pbhlth_code.columns=['보건소코드','자치구']
data_pbhlth_code.set_index('보건소코드',inplace=True)
data_pbhlth_code.to_dict()
data_pbhlth_code.to_dict()['자치구']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1952529247bb> in <module>
# ----> 1 data_pbhlth_code = pd.read_excel('../raw/지역사회건강조사 1차 전처리.csv',header=3)
#       2 data_pbhlth_code = data_pbhlth_code[data_pbhlth_code['시도코드'] == 11][['보건소코드','보건소명']]
#       3
#       4 data_pbhlth_code["보건소명"] = data_pbhlth_code["보건소명"].str.replace('보건소', '', regex=True)
#       5 data_pbhlth_code.columns=['보건소코드','자치구']
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1069                 ext = "xls"
#    1070             else:
# -> 1071                 ext = inspect_excel_format(
#    1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     947     assert content_or_path is not None
#     948
# --> 949     with get_handle(
#     950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw/지역사회건강조사 1차 전처리.csv'

# %%
df_raw1 = data_raw[['age','sex','pbhlth_code','qoa_01z1','pha_04z1','pha_05z1','pha_06z1','pha_07z1','pha_08z1','pha_09z1','phb_01z1','phb_02z1','phb_03z1','obb_01z1','mta_01z1','mtb_01z1','qoc_07z1','ena_01d1','ena_01e1']]
index = ['만나이','성별','보건소번호','주관적 건강수준','격렬한 신체활동 일수','격렬한 신체활동 시간(시)','격렬한 신체활동 시간(분)','중등도 신체활동 일수','중등도 신체활동 시간(시)','중등도 신체활동 시간(분)','걷기 실천 일수','걷기 실천 시간(시)','걷기 실천 시간(분)','체중조절 경험 여부','주관적 스트레스 수준','우울감 경험 여부','행복감 지수','사회환경_동네 자연환경','사회환경_동네 생활환경']
df_raw1.columns = index
df_raw2 = df_raw1.copy() # SettingWithCopyWarning 없애려고 넣음..없어도 돌아는 감
df_raw2['자치구'] = df_raw2['보건소번호'].map(data_pbhlth_code.to_dict()['자치구'])
df_raw2 = df_raw2.drop(['보건소번호'],axis=1)
df_raw2
# Out:
#        만나이  성별  주관적 건강수준  격렬한 신체활동 일수  격렬한 신체활동 시간(시)  격렬한 신체활동 시간(분)  \
# 0       61   2         4            1               5               0
# 1       66   1         3            1               5               0
# 2       89   2         5            0              88              88
# 3       27   1         4            1               0              10
# 4       42   2         3            2               0              30
# ...    ...  ..       ...          ...             ...             ...
# 22925   62   2         3            0              88              88
# 22926   65   1         4            7               2               0
# 22927   24   1         2            0              88              88
# 22928   56   2         3            0              88              88
# 22929   66   2         1            0              88              88
#
#        중등도 신체활동 일수  중등도 신체활동 시간(시)  중등도 신체활동 시간(분)  걷기 실천 일수  걷기 실천 시간(시)  \
# 0                3               1               0         7            1
# 1                0              88              88         7            1
# 2                0              88              88         0           88
# 3                1               0              10         7            0
# 4                2               0              10         5            0
# ...            ...             ...             ...       ...          ...
# 22925            7               1               0         5            0
# 22926            7               2               0         0           88
# 22927            0              88              88         7            0
# 22928            0              88              88         3            2
# 22929            7               1               0         7            1
#
#        걷기 실천 시간(분)  체중조절 경험 여부  주관적 스트레스 수준  우울감 경험 여부  행복감 지수  사회환경_동네 자연환경  \
# 0                0           1            3          2       5             2
# 1                0           4            2          2       8             2
# 2               88           4            1          2      77             9
# 3               30           3            2          2       8             1
# 4               20           1            3          2       6             2
# ...            ...         ...          ...        ...     ...           ...
# 22925           20           1            2          2       4             9
# 22926           88           2            2          2      10             2
# 22927           20           1            4          2       7             2
# 22928            0           1            4          2       7             1
# 22929            0           2            4          2      10             1
#
#        사회환경_동네 생활환경  자치구
# 0                 1  마포구
# 1                 1  마포구
# 2                 9  마포구
# 3                 1  마포구
# 4                 2  마포구
# ...             ...  ...
# 22925             1  금천구
# 22926             2  금천구
# 22927             1  금천구
# 22928             1  금천구
# 22929             1  금천구
#
# [22930 rows x 19 columns]

# %%
df_h = df_raw2[['만나이','성별','체중조절 경험 여부','자치구']]

# %%
df_h
print(df_h['체중조절 경험 여부'].value_counts(normalize = True))
df_hl1=df_h[df_h['체중조절 경험 여부'] != 9]
df_hl2=df_hl1[df_hl1['체중조절 경험 여부'] != 7]
df_hl2['체중조절 경험 여부'].value_counts(normalize = True)
# Out:
# 1    0.465068
# 4    0.283079
# 2    0.199389
# 3    0.052246
# 9    0.000131
# 7    0.000087
# Name: 체중조절 경험 여부, dtype: float64
# 1    0.465169
# 4    0.283141
# 2    0.199433
# 3    0.052257
# Name: 체중조절 경험 여부, dtype: float64

# %%
df_h.loc[df_h["체중조절 경험 여부"] < 3, :]
# Out:
#        만나이  성별  체중조절 경험 여부  자치구
# 0       61   2           1  마포구
# 4       42   2           1  마포구
# 5       74   1           1  마포구
# 8       51   1           1  마포구
# 9       22   1           1  마포구
# ...    ...  ..         ...  ...
# 22925   62   2           1  금천구
# 22926   65   1           2  금천구
# 22927   24   1           1  금천구
# 22928   56   2           1  금천구
# 22929   66   2           2  금천구
#
# [15236 rows x 4 columns]

# %%
data_pbhlth_code = pd.read_excel('../raw/지역사회건강조사 1차 전처리.csv',header=3)
data_pbhlth_code = data_pbhlth_code[data_pbhlth_code['시도코드'] == 11][['보건소코드','보건소명']]
data_pbhlth_code["보건소명"] = data_pbhlth_code["보건소명"].str.replace('보건소', '', regex=True)
data_pbhlth_code.columns=['보건소코드','자치구']
list_region = list(data_pbhlth_code.to_dict()['자치구'].values()) + ['서울시']
list_region.reverse()

# %%
list_df = []
for value in list_region:
    temp = df_hl2['자치구'] == value
    list_df.append(df_hl2[temp])
list_df[0] = df_hl2

# %%
list_age = ['19~200','19~44','45~64','65~74','75~200']
list_sex = ['계','남','여']
idx_sex = []
idx_age = []
idx_region = []
value_hl = ['체중조절 경험 여부']
for i, value1 in enumerate(list_region):
    for j in list_age:
        for k in list_sex:            
            temp = list_df[i][list_df[i]['만나이']>=int(j.split('~')[0])]
            temp1 = temp[temp['만나이'] < int(j.split('~')[1])]
            if k == '남':
                temp2 = temp1[temp1['성별'] == 1]
            elif k == '여':
                temp2 = temp1[temp1['성별'] == 2]
            else:
                temp2 = temp1
            temp3 = temp2['체중조절 경험 여부'].value_counts(normalize = True).to_dict()
            
            if 4 not in temp3:
                temp3[4] = 0
            if 1 not in temp3:
                temp3[1] = 0
            value_hl.append(round(100 - (temp3[3]+temp3[4])*100,1))
            
            if j == '19~200':
                idx_age.append('계')
            elif j == '75~200':
                idx_age.append('75 이상')
            else:
                idx_age.append(j)
            idx_sex.append(k)
            idx_region.append(value1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35af1a9a1b81> in <module>
#       5 idx_region = []
#       6 value_hl = ['체중조절 경험 여부']
# ----> 7 for i, value1 in enumerate(list_region):
#       8     for j in list_age:
#       9         for k in list_sex:
#
# NameError: name 'list_region' is not defined

# %%
df1 = pd.DataFrame({'체중조절 경험 여부':value_hl, '지역':idx_region,'연령별':idx_age,'성별':idx_sex})

df1 = df1.set_index(['지역','연령별','성별'])

df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2cf8b5e05823> in <module>
# ----> 1 df1 = pd.DataFrame({'체중조절 경험 여부':value_hl, '지역':idx_region,'연령별':idx_age,'성별':idx_sex})
#       2
#       3 df1 = df1.set_index(['지역','연령별','성별'])
#       4
#       5 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length
