# %%
import pandas as pd

data1 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (건강수준)_2019.csv')
data2 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (걷기)_2019.csv')
data3 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (격렬한 신체활동)_2019.csv')
data4 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (중등도 신체활동)_2019.csv')
data5 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (체중조절)_2019.csv')
data6 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (우울감)_2019.csv')
data7 = pd.read_csv('../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 (스트레스)_2019.csv')

# %%
list_df = [data1,data2,data3,data4,data5,data6,data7]
for i in list_df:
    i.set_index(['지역','연령별','성별'],inplace=True)

# %%
df = pd.concat([data1,data2,data3,data4,data5,data6,data7],axis=1, join='inner')

# %%
df
# Out:
#               주관적 건강수준  걷기 실천  격렬한 신체활동 실천  중등도 신체활동 실천  체중조절 경험 여부  우울감 경험률  \
# 지역  연령별   성별
# 서울시 계     계       39.3   59.6         16.2         10.4        66.5      6.3
#           남       44.4   62.3         20.4         12.3        60.0      4.6
#           여       35.3   57.5         13.0          8.9        71.5      7.7
#     45~64 계       36.9   59.0         17.3         12.0        70.6      5.9
#           남       40.8   58.8         20.1         12.9        60.9      4.5
# ...                ...    ...          ...          ...         ...      ...
# 강남구 계     남       50.1   59.1         20.5         11.5        66.8      4.6
#           여       42.6   55.6         12.1         10.0        73.8      6.6
#     45~64 계       46.7   55.8         14.5          9.1        72.4      3.1
#           남       50.0   58.7         14.7          8.7        68.7      2.7
#           여       44.3   53.7         14.4          9.5        75.1      3.5
#
#               주관적 스트레스 수준
# 지역  연령별   성별
# 서울시 계     계          24.5
#           남          22.6
#           여          26.1
#     45~64 계          23.1
#           남          22.5
# ...                   ...
# 강남구 계     남          27.1
#           여          27.9
#     45~64 계          22.8
#           남          26.7
#           여          19.9
#
# [156 rows x 7 columns]

# %%
df.to_csv("../raw/지역사회건강조사 (전처리된 데이터)_2019/지역사회건강조사 통합 테이블_2019.csv", mode='w',encoding = 'utf-8-sig')
