# %%
import openpyxl
import pandas as pd

xlsxFile = '../raw/전국+도시림+현황통계(2019)-최종.xlsx'
sheetList = []

wb = openpyxl.load_workbook(xlsxFile,read_only=True)

for i in wb.sheetnames:
    sheetList.append(i)

xlsx = pd.ExcelFile(xlsxFile)

print(sheetList)
# Out:
# ['간지 1', '간지 2', '2.도시림 면적 현황', '2-1.생활권 도시림 면적 현황', '2-2.생활권 도시림 면적 현황(산자법)', '2-3.생활권 도시림 면적 현황(도시공원법)', '2-4.1인당 생활권 도시림 면적', '간지 3', '3.도시림 면적 현황 세부내역 (시도)', '3-1도시림 면적 현황 세부내역(시군구)', '간지 4', '4. 산자법에 의한 산림과 수목(시도)', '4-1. 산자법에 의한 산림과수목(시군구)', '간지 5', '5.도시공원법에 의한 공원녹지(시도) ', '5.1 도시공원법에 의한 공원녹지(시군구)', '간지 6 ', '6.도시림면적률(시도)', '6-1.도시림면적률(시군구)', '간지 7', '7. 1인당도시림면적(시도)', '7-1. 1인당 도시림면적(시군구)', '간지 8', '8. 연도별 도시림현황', '8-1.도시지역 인구의 변화', '8-2.산림면적의 변화', '8-3. 도시림 면적의 변화', '8-4.생활권 도시림 면적의 변화', '8-5.1인당 도시림 면적의 변화', '8-6.1인당 생활권 도시림 면적의 변화', '기초자료']

# %%
df = pd.read_excel(xlsx, '7-1. 1인당 도시림면적(시군구)')
df = df.drop(df.index[0:4])
df = df.rename(columns=df.iloc[0])
df = df.drop(df.index[0:4])
df = df.drop(df.index[26:])
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df1 = df[['시군구','총도시림 면적\n(B=F+J)','생활권도시림\n면적\n(C=G+K)','1인당 총도시림면적(㎡/인)\n(D=B/A)','1인당 생활권도시림면적(㎡/인)\n(E=C/A)']]
df1['시군구'][8] = '서울시'
df1.columns = ['자치구','총 도시림 면적','생활권 도시림 면적','1인당 총 도시림 면적','1인당 생활권 도시림 면적']
df1.set_index("자치구",inplace = True)
df1
# Out:
# C:\Users\gimhu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               총 도시림 면적       생활권 도시림 면적 1인당 총 도시림 면적 1인당 생활권 도시림 면적
# 자치구
# 서울시   180287524.337675  66846771.337675    18.530737       6.870802
# 종로구         13277114.3        2501869.3    87.759365      16.536911
# 중구           5417625.7        1506737.7    42.938755      11.942029
# 용산구            2005971           809094      8.77234        3.53826
# 성동구            1388926          1184497     4.616074       3.936658
# 광진구         6073160.28       1287528.28    17.285215       3.664518
# 동대문구        1470284.05        847482.05     4.246995       2.447998
# 중랑구            6274698          1477730    15.804687       3.722101
# 성북구            8813956          1009189    19.911795        2.27988
# 강북구           11500610          2099240    36.631513       6.686457
# 도봉구            2992345          1452016     8.976263       4.355673
# 노원구           14715090          1457052     27.61297       2.734168
# 은평구           11318891          2608784    23.579451       5.434604
# 서대문구           6748518          1028651     21.81184       3.324696
# 마포구         3977249.95       3956309.95    10.633363      10.577379
# 양천구            3659173          1860690     7.986583       4.061179
# 강서구     8294106.057675   4322172.057675    14.015144       7.303483
# 구로구            3432140          1325089     8.439744       3.258437
# 금천구            3126930           413950    13.431253       1.778059
# 영등포구           2558024          2525751      6.95724       6.869465
# 동작구            3862343          2338377     9.754303       5.905544
# 관악구           15833597           539962    31.661242       1.079721
# 서초구           16751343         16088754    38.881922      37.343972
# 강남구           14160969          4560597    25.975375       8.365474
# 송파구            5691832          5685855     8.420356       8.411513
# 강동구            6942628          3959394    15.921012       9.079784

# %%
df1.to_csv("../raw/도시림 데이터 정리.csv", mode='w',encoding = 'utf-8-sig')
